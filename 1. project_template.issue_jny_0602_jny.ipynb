# %% [markdown]
# # 경제지표와 경제성장률과의 영향도 분석
# #### - GDP, Growth, Imports, Exports, CPI

# %% [markdown]
# - 2023. 05. 26 ~ 2023. 06. 2
# - 리더: 정남용
# - 정의: Global Economy 관련 지표를 다운받아 통계분석을 수행함
# - 목적: 인터넷에서 관련 데이터 수집하여 데이터를 분석하는 기슬 습득
# - 범위: 데이터 수집 - EDA 수행 - 통계분석 - 가설검증 - 시각화

# %% [markdown]
# ## *   기간: 2023.05.26 ~ 2023.06.02 (총 5일)

# %% [markdown]
# ## [할 일 목록]

# %% [markdown]
# ### [1일차 - 5/26]

# %% [markdown]
# ### 1.   첫 번째 우선순위 - 분석 대상, 범위, 내용

# %% [markdown]
# ###### - 데이터 수집 대상 및 범위 확정(GDP, Population, Growth, Imports, Exports, CPI)
# ###### - 데이터 구성, 연계관계 검토 및 상관성, 정규성 검증 방안 정의

# %% [markdown]
# ### 2.   두 번째 우선순위 - 수행방안

# %% [markdown]
# ###### -  회귀분석을 통한 가설검증 수행방안 정리

# %% [markdown]
# ### [2일차 - 5/30]

# %% [markdown]
# ### 1.   첫 번째 우선순위 - EDA 수행

# %% [markdown]
# ###### -  EDA 수행을 위한 자료형 변환 등 전처리 수행

# %% [markdown]
# ### 2.   두 번째 우선순위 - 데이터 탐색 및 상관관계 분석

# %% [markdown]
# ###### - 정규성(Shapiro-Wilk 검정), 상관(상관행렬)성 검증

# %% [markdown]
# ### [3일차 - 5/31] - 통계처리 및 시각화

# %% [markdown]
# - 회귀분석, 가설수립, 가설검증, 시각화 수행

# %% [markdown]
# ### [4일차 - 6/1]

# %% [markdown]
# ##### - 데이터 분석 결과 정리 및 Presentation 연습

# %% [markdown]
# ### [5일차 - 6/2]

# %% [markdown]
# ##### - Project 수행결과 발표

# %% [markdown]
# ## [이슈 항목]

# %% [markdown]
# ### 1.   프로젝트 중 발생한 이슈 항목을 추가합니다.

# %% [markdown]
# ### 2.   프로젝트 중 발생한 이슈 항목을 추가합니다.

# %% [markdown]
# ### 3.   프로젝트 중 발생한 이슈 항목을 추가합니다.
